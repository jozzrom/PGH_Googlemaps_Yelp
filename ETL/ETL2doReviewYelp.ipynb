# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/YelpReviewBusinessLimpio.csv"
df = pd.read_csv(archivo_csv)

# Lista de nombres a filtrar, con posibles variaciones en mayúsculas/minúsculas y errores tipográficos
nombres_a_filtrar = ["starbucks", "mcdonald's", "kfc", "subway", "domino's pizza"]

# Filtrar los nombres en la columna 'name' (ignorando mayúsculas/minúsculas y errores tipográficos)
filtro = df['name'].str.lower().str.replace('[^\w\s]', '').isin(nombres_a_filtrar)
resultados_filtrados = df[filtro]

# Mostrar los resultados con display
display(resultados_filtrados)

# Guardar los resultados en un archivo CSV
resultados_filtrados.to_csv("Restaurants.csv", index=False)
# Out:
# C:\Users\Fede\AppData\Local\Temp\ipykernel_5480\1140488647.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   filtro = df['name'].str.lower().str.replace('[^\w\s]', '').isin(nombres_a_filtrar)
#               name          city state  review_count  \
# 19240    Starbucks     Nashville    PA            65
# 19241    Starbucks     Nashville    PA            65
# 19242    Starbucks     Nashville    PA            65
# 19243    Starbucks     Nashville    PA            65
# 19244    Starbucks     Nashville    PA            65
# ...            ...           ...   ...           ...
# 4265905        KFC      Edmonton    IN             5
# 4265906        KFC      Edmonton    IN             5
# 4265907        KFC      Edmonton    IN             5
# 4265931     Subway  Green Valley    FL             6
# 4265932     Subway  Green Valley    FL             6
#
#                                                 attributes  \
# ...

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/YelpReviewBusinessLimpio.csv"
df = pd.read_csv(archivo_csv)

# Filtrar las filas donde el nombre de negocio ("name") es igual a "McDonald's" (sin importar mayúsculas o minúsculas)
filtro = df['name'].str.lower() == "domino's pizza"
resultados_filtrados = df[filtro]

# Mostrar los resultados con display
display(resultados_filtrados)

# Guardar los resultados filtrados en un archivo CSV llamado "McDonaldsYelp.csv"
archivo_salida = "domino's pizzaYelp.csv"
resultados_filtrados.to_csv(archivo_salida, index=False)
# Out:
#                    name     city state  review_count  \
# 35811    Domino's Pizza  Oldsmar    PA            20
# 35812    Domino's Pizza  Oldsmar    PA            20
# 35813    Domino's Pizza  Oldsmar    PA            20
# 35814    Domino's Pizza  Oldsmar    PA            20
# 35815    Domino's Pizza  Oldsmar    PA            20
# ...                 ...      ...   ...           ...
# 4257247  Domino's Pizza   Tucson    FL            15
# 4257248  Domino's Pizza   Tucson    FL            15
# 4257249  Domino's Pizza   Tucson    FL            15
# 4257250  Domino's Pizza   Tucson    FL            15
# 4257251  Domino's Pizza   Tucson    FL            15
#
#                                                 attributes  \
# 35811    {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 35812    {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 35813    {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 35814    {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# ...

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/Restaurants.csv"
df = pd.read_csv(archivo_csv)

# Ordenar el DataFrame por coincidencia del nombre en la columna "business_id"
df_ordenado = df.sort_values(by=['business_id'])

# Mostrar los resultados con display
display(df_ordenado)

# Guardar los resultados en un archivo CSV
archivo_salida = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocal.csv"
df_ordenado.to_csv(archivo_salida, index=False)
# Out:
#             name          city state  review_count  \
# 14731     Subway         Tampa    DE             5
# 14730     Subway         Tampa    DE             5
# 14729     Subway         Tampa    DE             5
# 10521  Starbucks     St. Louis    NJ            39
# 10520  Starbucks     St. Louis    NJ            39
# ...          ...           ...   ...           ...
# 2564         KFC  Indianapolis    FL            13
# 2565         KFC  Indianapolis    FL            13
# 2566         KFC  Indianapolis    FL            13
# 2559         KFC  Indianapolis    FL            13
# 2567         KFC  Indianapolis    FL            13
#
#                                               attributes  \
# 14731  {'Ambience': "{'touristy': False, 'hipster': F...
# 14730  {'Ambience': "{'touristy': False, 'hipster': F...
# 14729  {'Ambience': "{'touristy': False, 'hipster': F...
# 10521  {'BusinessParking': "{'garage': False, 'street...
# 10520  {'BusinessParking': "{'garage': False, 'street...
# ...

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocal.csv"
df = pd.read_csv(archivo_csv)

# Mostrar los tipos de datos de las columnas
print(df.dtypes)
# Out:
# name             object
# city             object
# state            object
# review_count      int64
# attributes       object
# categories       object
# review_id        object
# user_id          object
# business_id      object
# stars_y         float64
# text             object
# anio              int64
# mes               int64
# dia               int64
# dtype: object

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/Restaurants.csv"
df = pd.read_csv(archivo_csv)

# Crear una columna de fecha combinando las columnas "anio," "mes," y "dia"
df['date'] = pd.to_datetime(df[['anio', 'mes', 'dia']])

# Ordenar el DataFrame por la columna 'date' de menor a mayor
df_ordenado = df.sort_values(by='date')

# Mostrar los resultados con display
display(df_ordenado)

# Guardar los resultados en un archivo CSV
archivo_salida = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocalxFecha.csv"
df_ordenado.to_csv(archivo_salida, index=False)

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocal.csv"
df = pd.read_csv(archivo_csv)

# Filtrar las filas donde la columna 'name' contiene la palabra "Subway"
df_filtrado = df[df['name'].str.contains('Subway', case=False)]

# Mostrar los resultados con display
display(df_filtrado)

# Guardar los resultados filtrados en un archivo CSV llamado "SubwayYelp.csv"
archivo_salida = "SubwayYelp.csv"
df_filtrado.to_csv(archivo_salida, index=False)
# Out:
#          name        city state  review_count  \
# 0      Subway       Tampa    DE             5
# 1      Subway       Tampa    DE             5
# 2      Subway       Tampa    DE             5
# 23     Subway  Clearwater    FL             5
# 24     Subway  Clearwater    FL             5
# ...       ...         ...   ...           ...
# 18531  Subway   Bellville    MO             6
# 18532  Subway   Bellville    MO             6
# 18533  Subway   Bellville    MO             6
# 18534  Subway   Bellville    MO             6
# 18535  Subway   Bellville    MO             6
#
#                                               attributes  \
# 0      {'Ambience': "{'touristy': False, 'hipster': F...
# 1      {'Ambience': "{'touristy': False, 'hipster': F...
# 2      {'Ambience': "{'touristy': False, 'hipster': F...
# 23     {'RestaurantsAttire': "u'casual'", 'Ambience':...
# 24     {'RestaurantsAttire': "u'casual'", 'Ambience':...
# ...                                                  ...
# ...

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocal.csv"
df = pd.read_csv(archivo_csv)

# Filtrar las filas donde la columna 'name' contiene la palabra "Subway"
df_filtrado = df[df['name'].str.contains('KFC', case=False)]

# Mostrar los resultados con display
display(df_filtrado)

# Guardar los resultados filtrados en un archivo CSV llamado "SubwayYelp.csv"
archivo_salida = "KFCYelp.csv"
df_filtrado.to_csv(archivo_salida, index=False)
# Out:
#       name          city state  review_count  \
# 170    KFC     Greenwood    FL            39
# 171    KFC     Greenwood    FL            39
# 172    KFC     Greenwood    FL            39
# 173    KFC     Greenwood    FL            39
# 174    KFC     Greenwood    FL            39
# ...    ...           ...   ...           ...
# 18565  KFC  Indianapolis    FL            13
# 18566  KFC  Indianapolis    FL            13
# 18567  KFC  Indianapolis    FL            13
# 18568  KFC  Indianapolis    FL            13
# 18569  KFC  Indianapolis    FL            13
#
#                                               attributes  \
# 170    {'WiFi': "'free'", 'OutdoorSeating': 'False', ...
# 171    {'WiFi': "'free'", 'OutdoorSeating': 'False', ...
# 172    {'WiFi': "'free'", 'OutdoorSeating': 'False', ...
# 173    {'WiFi': "'free'", 'OutdoorSeating': 'False', ...
# 174    {'WiFi': "'free'", 'OutdoorSeating': 'False', ...
# ...                                                  ...
# ...

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocal.csv"
df = pd.read_csv(archivo_csv)

# Filtrar las filas donde la columna 'name' contiene la palabra "Subway"
df_filtrado = df[df['name'].str.contains('KFC', case=False)]

# Mostrar los resultados con display
display(df_filtrado)

# Guardar los resultados filtrados en un archivo CSV llamado "SubwayYelp.csv"
archivo_salida = "KFCYelp.csv"
df_filtrado.to_csv(archivo_salida, index=False)

# %%
Starbucks

# %%
import pandas as pd

# Cargar el archivo CSV
archivo_csv = "C:/Users/Fede/Documents/Henry/ProyectoFinal/Yelp/RestaurantsOrdenadoxLocal.csv"
df = pd.read_csv(archivo_csv)

# Filtrar las filas donde la columna 'name' contiene la palabra "Subway"
df_filtrado = df[df['name'].str.contains('Starbucks', case=False)]

# Mostrar los resultados con display
display(df_filtrado)

# Guardar los resultados filtrados en un archivo CSV llamado "SubwayYelp.csv"
archivo_salida = "StarbucksYelp.csv"
df_filtrado.to_csv(archivo_salida, index=False)
# Out:
#             name         city state  review_count  \
# 3      Starbucks    St. Louis    NJ            39
# 4      Starbucks    St. Louis    NJ            39
# 5      Starbucks    St. Louis    NJ            39
# 6      Starbucks    St. Louis    NJ            39
# 7      Starbucks    St. Louis    NJ            39
# ...          ...          ...   ...           ...
# 18549  Starbucks  New Orleans    CA            15
# 18550  Starbucks  New Orleans    CA            15
# 18551  Starbucks  New Orleans    CA            15
# 18552  Starbucks  New Orleans    CA            15
# 18553  Starbucks  New Orleans    CA            15
#
#                                               attributes  \
# 3      {'BusinessParking': "{'garage': False, 'street...
# 4      {'BusinessParking': "{'garage': False, 'street...
# 5      {'BusinessParking': "{'garage': False, 'street...
# 6      {'BusinessParking': "{'garage': False, 'street...
# 7      {'BusinessParking': "{'garage': False, 'street...
# ...
