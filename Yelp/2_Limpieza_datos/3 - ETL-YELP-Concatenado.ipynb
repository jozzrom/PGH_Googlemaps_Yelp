# %% [markdown]
# # Explorar los datos de Review

# %%
import pandas as pd

# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp1.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Mostrar el DataFrame usando display
display(df)
# Out:
#                      review_id                 user_id  \
# 0       KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1       BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2       saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3       AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4       Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                        ...                     ...
# 599995  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 599996  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 599997  X8QM0_gTsvEatcslkuRDwQ  t8fTihkSkf2KpP_4Q_kPow
# 599998  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 599999  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                    business_id  stars  useful  funny  cool  \
# 0       XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1       7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2       YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# 3       kxX2SOes4o-D3ZQBkiMRfA      5       1      0     1
# 4       e4Vwtrqf-wpJfwesgvdgxQ      4       1      0     1
# ...                        ...    ...     ...    ...   ...
# 599995  cxupofYLq46bxBHpKyFwsQ      4       2      0     1
# 599996  WVX0JKV9ZP-r9bz0A4xAVw      4      27     15    24
# 599997  uO39--k_hrCFgZh-Bl8m8A      4       1      0     2
# 599998  SoEnVtFQWEhBUBQXq9O5Ag      5       2      0     2
# 599999  A9rVxmIBtHZRvNhbBaGAWg      5       1      0     1
#
#                                                      text                 date
# 0       If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1       I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2       Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3       Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4       Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# ...                                                   ...                  ...
# 599995  Stayed here the wknd of Labor Day/Decadence.  ...  2019-09-17 18:26:11
# 599996  Less crowded than Parksdale if you're craving ...  2020-01-27 14:19:10
# 599997  I've gone by this place and I've been wanting ...  2016-05-13 03:37:03
# 599998  I love OG!!! We started going to Metazoa becau...  2020-11-08 01:59:14
# 599999  One of the best Szechwan restaurants you can f...  2021-04-13 04:34:15
#
# [600000 rows x 9 columns]

# %% [markdown]
# # Se divide en 7 partes el archivo review de Yelp para poder trabajarlo en local.

# %% [markdown]
# # Se eliminan las columnas que no se utilizaran y se filtra por fechas desde 2017 en adelante para la 1era parte.

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp1.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review1.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review1.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                      review_id                 user_id  \
# 0       KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 4       Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# 24      lUUhg8ltDsUZ9h0xnwY4Dg  RreNy--tOmXMl1en0wiBOg
# 30      -P5E9BYUaK7s3PwBF5oAyg  Jha0USGDMefGFRLik_xFQg
# 31      YbMyvlDA2W3Py5lTz8VK-A  4hBhtCSgoxkrFgHa4YAD-w
# ...                        ...                     ...
# 599994  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 599995  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 599996  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 599998  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 599999  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                    business_id  stars  \
# 0       XQfwVwDr-v0ZS3_CbbE5Xw      3
# 4       e4Vwtrqf-wpJfwesgvdgxQ      4
# 24      cPepkJeRMtHapc_b2Oe_dw      4
# 30      bMratNjTG5ZFEA6hVyr-xQ      5
# 31      bbEXAEFr4RYHLlZ-HFssTA      5
# ...                        ...    ...
# 599994  c6qyEglw37vrDnUXabvWvw      5
# 599995  cxupofYLq46bxBHpKyFwsQ      4
# 599996  WVX0JKV9ZP-r9bz0A4xAVw      4
# 599998  SoEnVtFQWEhBUBQXq9O5Ag      5
# 599999  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                      text                date
# 0       If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 4       Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# 24      I was really between 3 and 4 stars for this on... 2018-07-17 03:30:07
# 30      First time there and it was excellent!!! It fe... 2017-02-19 13:32:05
# 31      Great burgers,fries and salad!  Burgers have a... 2017-01-02 03:17:34
# ...                                                   ...                 ...
# 599994  Incredibly responsive, communicates well and e... 2018-05-08 23:59:01
# 599995  Stayed here the wknd of Labor Day/Decadence.  ... 2019-09-17 18:26:11
# 599996  Less crowded than Parksdale if you're craving ... 2020-01-27 14:19:10
# 599998  I love OG!!! We started going to Metazoa becau... 2020-11-08 01:59:14
# 599999  One of the best Szechwan restaurants you can f... 2021-04-13 04:34:15
#
# [299799 rows x 6 columns]

# %% [markdown]
# # Se realizan los mismos pasos para el resto de las partes.

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp2.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review2.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review2.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                       review_id                 user_id  \
# 0        FzUIuyEv0-IGDD-HgNzMFw  ygkSutTb8BXT2FWet7HB4w
# 1        X4pf__trHaFzzYCQnQNtSg  WDms6ne7odON8vtdL-b-xA
# 2        OaGJJMW1Bk2XD2yfmMlffg  ahgaIIujY6R8HsEJfRnLUw
# 3        d8a0jFNvN7k-4CSv4d2HZQ  LzPNpoqbx3Pw18yX_aEHwA
# 4        FqJqBbDqrs-GK2HUW13tdQ  B7laWmiMZHgsxiHk2U9H9A
# ...                         ...                     ...
# 1199994  5g1GgoEJoAe5VQ_YI3r1dA  uIlCf7VLBwXyw-hPwAg7DA
# 1199995  LRKTqfwebYI_ykIBe_hD0A  CaoImVzU4uMREOlT0HiEsg
# 1199997  KngJAp9Ezj2UG5gjn_0EDQ  arErTRPKj6vmaJSq9KeYaA
# 1199998  mGAVwDhyFhj09YiGNOr2VQ  wZLOsbGjrV5J7lf2bS2HCg
# 1199999  vu7UfOLsUgCkkCl-nFd95A  aXOp6VtWZdQakAxZKgf_uQ
#
#                     business_id  stars  \
# 0        PVqNBGihp6yNv6HTQf7CjA      5
# 1        STtVemevd30WoiZWn_taiQ      5
# 2        MfyUK58sdUokMdIZNdem0w      1
# 3        7IU6885SDuzEA9JfrP--uQ      5
# 4        bqXjSL_8Pu_4xPL84EUjDw      5
# ...                         ...    ...
# 1199994  HuECL2Vymf6WXvnE1_bvRA      5
# 1199995  LSh18uOYKvYUtVoRXAsrtw      5
# 1199997  VWy97TpzjreU_78xotES2A      5
# 1199998  z5BLSMc92pwbGEqeaUPmDg      5
# 1199999  lS_P90LKJbVb2vFy5_nIEg      5
#
#                                                       text                date
# 0        I live nearby and was tired of the same old na... 2018-08-01 13:18:03
# 1        This Pollo Tropical is great! Quick and friend... 2021-04-11 21:30:56
# 2        Not happy with this place at all. Saw somethin... 2020-12-01 20:46:21
# 3        This is hands down my new breakfast food spot,... 2021-04-06 15:43:59
# 4        What a cool place. Have a beer and a haircut. ... 2020-08-06 19:57:03
# ...                                                    ...                 ...
# 1199994  Love this place! Their matcha green tea latte ... 2019-05-08 19:52:52
# 1199995  This is an INCREDIBLE find right in the heart ... 2019-06-30 13:59:46
# 1199997  Wow punk rock times ten . The steps so hardcor... 2019-07-26 01:11:17
# 1199998  By far my favorite bar in the Arnold area.  Th... 2019-05-01 23:56:14
# 1199999  Outstanding job.  Jim St. Vrain is quite knowl... 2019-05-18 00:23:06
#
# [604070 rows x 6 columns]

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp3.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review3.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review1.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                       review_id                 user_id  \
# 4        ygAtxZ1Gaimqj8IZGPobRA  W9zN7u6b-e3bkZ69W92fig
# 7        PlrmW2F7dksNL9JH2tO3-Q  i5xSc8B5LrOW7MFNGSFVuw
# 8        J29BCSfMus7NPzVRyRstIg  VBjAZ4JxPmaqRqBVbhjRGQ
# 10       lyD5iMWEuAM3sWQCHRlOig  KwI-RhKF_5EIK2-jRdWNfg
# 13       rwUvvaUmQzYU4Ca7iGz5nA  ObZnTiwMA-4gaTqa1_mB6A
# ...                         ...                     ...
# 1199986  MOIvcRrGKOoRrclXCboUog  1Nm8RCdOWCXXeKiQWlR5Ew
# 1199989  w_DkugGUJQfK8ColecS3sA  kDoGqGCaBSl45J4iuXA4pg
# 1199991  lJbN8xKLHGowvxi-xtNQVQ  pMIDgk56JtJl-XRlPYGp-w
# 1199995  Q5lUOm4N05NJz8RlrG0nog  hfLkWDNieilUbTuEkybFLg
# 1199996  bct-hnZ8-eWNJh_hMO_flw  6IzPa7zHSyuIe5paysUS7g
#
#                     business_id  stars  \
# 4        BX3LLonrLLLfVX-tNrE7yA      5
# 7        J1bG9ezYHMkzqV1yRsVtQQ      4
# 8        aSkAeE5w4CEAXdUrlVEygA      1
# 10       N4TImiSncqw-FTXT2a-sVw      5
# 13       akPsFyMCb2D90nCsSXBZfQ      3
# ...                         ...    ...
# 1199986  -aZnEYYTqwE5Hc5YKp_HjQ      5
# 1199989  ADYj43RUBPLibJyE0RJ8lQ      5
# 1199991  x3pTbsABLypwEoTdwQOmSg      1
# 1199995  6HNszS8BiN0YnZo0EAR-cg      5
# 1199996  cIBr1KeRLTpgvTpF8z2nFQ      1
#
#                                                       text                date
# 4        New location is beautiful! This location is st... 2017-11-28 18:22:51
# 7        Came here at the recommendation of the concier... 2017-04-06 01:04:26
# 8        The worst Domino's I've ever been to. I stoppe... 2018-06-15 09:47:33
# 10       Jared was able to fit me in the day I called. ... 2018-06-16 19:13:00
# 13       We drove up to the Hilltop for dinner based on... 2018-07-02 02:55:21
# ...                                                    ...                 ...
# 1199986  Welcoming atmosphere with people of all differ... 2017-07-29 19:27:12
# 1199989  Love the food there , especially boneless spar... 2018-04-05 02:23:06
# 1199991  My niece recently bought some mini chimisi fro... 2018-02-12 00:04:05
# 1199995  Went through the drive through last night for ... 2017-05-29 02:51:08
# 1199996  I was looking for a good local bar to watch th... 2017-11-21 21:38:09
#
# [714653 rows x 6 columns]

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp4.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review4.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review4.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                       review_id                 user_id  \
# 2        YKxrVp07Q53x-P2buThANA  -g8mbRk54fHks-38JkwwkA
# 3        XITVk2Ggfus_YFT8it82WQ  SdurPEg9GYWvBp-NcEF4ew
# 4        Id1E7Jd55cpWC0S94WBgzw  mjCZ94x9qHzeexz0_J4ruA
# 5        fXd3tmkyYHHADIjmAHPE4g  1-D3QVbNFREg1_Axm3xk0Q
# 6        N_j3rAU6I5Cbdyh-b2Lv2g  4A5vxdLlC9fcb9ViGLh0eg
# ...                         ...                     ...
# 1199995  iFM1mN1OUEHjWDHViOFXqA  _f7Goq0_ha76YUJYnDepcg
# 1199996  WoyWPBfIVFruVpp7_HUGtw  aMjLR96KI5M2nMDDU1FT4g
# 1199997  rkBB5IojwNxGuFUn6rGJeA  xJpll6rEHzYeOe1XSV7DXw
# 1199998  -lMNkF8XuHxef82HkoNhgw  gWI2w3BEsuVdB5FlYJZWCw
# 1199999  rNH1GQA8jsm6rTuAuczaZA  vRVI0ourDUWQY7PLt65e-A
#
#                     business_id  stars  \
# 2        6lwgfwZkEnRHYcp6jKWlIA      4
# 3        iDrmpQwGAAmftLzWqxEomg      5
# 4        rjFGFcTduZ5wh-5pl1IbCg      5
# 5        6KoyHbN2qSUsioqrjXLeEg      5
# 6        Dbgv4FjJ89mkhRz9fefBpw      5
# ...                         ...    ...
# 1199995  vEsBq8kDrkQ-Yi3cWJpV6A      5
# 1199996  3WGHOrb3MwoBJNJCkHwCdg      5
# 1199997  f1zEJ0teMABD3urmvikjgw      5
# 1199998  j7LZM6rf4Bf33exo6XXKGA      1
# 1199999  sYhHFlE1l9wWrWmhRjAlxw      1
#
#                                                       text                date
# 2        Food was great and came out in good time. Our ... 2018-10-03 21:44:03
# 3        What a great lunch today, my waitress Ms.Jonni... 2017-05-11 21:34:54
# 4        Tours by Isabelle is a professional outfit. I ... 2017-01-05 01:43:38
# 5        Great atmosphere, great service and amazing fo... 2017-10-04 01:55:12
# 6        This is the first time posting on Yelp.  Yet I... 2018-08-25 19:33:08
# ...                                                    ...                 ...
# 1199995  Amazing customer service!!!!! Got exactly what... 2019-11-05 21:25:56
# 1199996  Sierra Tucson changed my life. The month that ... 2020-03-04 20:14:03
# 1199997  This place is amazing. My window was smashed o... 2020-11-23 22:59:24
# 1199998  The quality of the staff needs a lot of work..... 2019-09-11 04:20:10
# 1199999  I have never been treated so poorly by an esta... 2019-04-15 22:46:55
#
# [646807 rows x 6 columns]

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp5.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review5.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review5.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                       review_id                 user_id  \
# 0        8S4tqXXB7KoSWLPuU6H9UA  fxHHP4nQDIfv1heJSgQtvQ
# 1        B7B7WmlS8qBVmylGU9FJng  kkPgJv6KBFN15caG7NYYlg
# 2        l6gs8FVsbHERT-zI1mLmOQ  IsfzrB80aWj9jYVaG3WrzA
# 3        _6-suMMDZ_8m3qpjvrdtBA  crGnkZCp9Rr-Frclf6kjPg
# 4        xgULgSlXSDNmA7IxvS3qcQ  pj7MtKv6rLlMvOriCTaJDQ
# ...                         ...                     ...
# 1199978  NcOtEQJjQGv268H9GcRLYA  WqeE5e5ROfaVEgkb9dAkiQ
# 1199980  NuXNUfNEQZMhDJy_pzfKqw  bbt00DeGm_Ofk_7pF_VHrg
# 1199981  TMfr6wNyzWCY_BO0fygs-Q  ecTzQfyycPiXkB3hkHDTPw
# 1199984  RHQC9COXfwoPAoveRShVjw  msFsKlA7TLYDczGiyEY0zg
# 1199985  zl5NxYwSgepEVmF7Kc_PAA  0kcRK0ZbMSy651okpOGPqA
#
#                     business_id  stars  \
# 0        eikRexw04kC6siBDkFnayQ      5
# 1        l7VClHY6vvoTBSCP1-ZUmw      5
# 2        mK4gpsdN7qqb2MMUYbQb7A      4
# 3        pGM44vXYa6lke-dU4h-xpA      5
# 4        pfl45YV5Us5NvDm5cLremw      5
# ...                         ...    ...
# 1199978  YQvVAKCpPcOJHwwrMad4KA      4
# 1199980  jOaJ4PFGhGiM8fhuYcYFRg      5
# 1199981  nTPTqC40pXELp3LOrCtXIA      5
# 1199984  6FX09pOrazvGT9s6_nQ7CQ      5
# 1199985  tVELQMCI0485CPvgtTlMDA      5
#
#                                                       text                date
# 0        In my 43 years on planet earth, I've never had... 2020-11-23 18:20:19
# 1        We were very happy with this business when we ... 2020-12-04 20:14:18
# 2        We pulled into the dock from our morning fishi... 2018-02-20 02:17:07
# 3        Super awesome staff from the moment you walk i... 2020-09-12 00:07:20
# 4        We stayed just one night, our first little tri... 2020-09-01 05:15:23
# ...                                                    ...                 ...
# 1199978  Great local Indian food. Portion of food and p... 2017-07-17 04:37:16
# 1199980  This is the best cheese steak in town. Curry c... 2017-03-26 18:09:36
# 1199981  NOLA has been long overdue for a good, compreh... 2018-08-13 18:20:25
# 1199984  Coffee was excellent\nFood was delicious and p... 2017-06-15 22:16:51
# 1199985  My wife and I went in last week and wow, just ... 2017-11-18 02:30:41
#
# [614978 rows x 6 columns]

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp6.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review6.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review6.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                       review_id                 user_id  \
# 0        M-bBlFEkwMbo55ltiSJtQw  NvVVUaXEF3Rh5kpABndmOA
# 4        CL-5fug023ms3H0Bfj12gQ  tLZWTsvtOMNEbe9vL6e67w
# 6        P7-8hPhCUO85I-GIKHcBhQ  j3pH0tFM1_KpOyUnHggfbg
# 8        -cwIHC-gDqKQY6_R__N-cQ  bQI9tuBTusP58fsw8yKgDQ
# 12       IlwuZAtAbeiDKee3DPLvzw  D6bOJnI4rAvPrU4wisxzRA
# ...                         ...                     ...
# 1199987  9yxhzS_Xd_VOxgSrnBdp0w  BQkdnYJI5s0uDBAXLPYzmA
# 1199988  hHPhepr2cPtEwcrVMRJNcA  k7Zjd36zIIZZPX-KdivZlw
# 1199992  5Rwc4Uws-SmUAOklCvMO_w  9UNkH6XOUs7ZNkSFZGOAmQ
# 1199997  y8CS4z4alNT_Q4JNF-7tvQ  wN2f5qD2tbiD0xpZsrUC2A
# 1199998  TTH0z_M_C6ZHGKzvs6H7iw  3khXY9FdsXI10bf5539pOg
#
#                     business_id  stars  \
# 0        wP4m78FJc-fyg8fLhHQ-ZQ      5
# 4        s1Ye1o9JL77vs5g3F0CF5A      1
# 6        i71_nBmHyEEQ95C4q5ywfQ      4
# 8        k6IiU_AZOZc6myOXfV1-IA      1
# 12       wulFpnfqcRP8PNIcHaVdAA      5
# ...                         ...    ...
# 1199987  csfMjRRfr-sku6L6bhEf_A      1
# 1199988  c-iKAO2GBzSKjm7y1Oljcw      4
# 1199992  5j9TfW8RrdkpaHlaBwt6bQ      4
# 1199997  xhAzk9qYpHR-nu_0sZIcWg      2
# 1199998  GEdrmeb5ubO2Gq5MgMxDtQ      5
#
#                                                       text                date
# 0        I have been shopping Costco for over 36 years ... 2018-08-03 08:48:06
# 4        Worse service!!! Slower than slow, give yourse... 2018-04-26 19:05:52
# 6        This was my first visit to the Frog Pond after... 2018-01-08 19:27:11
# 8        Long story short. They take my card info and t... 2017-07-17 04:25:23
# 12       Cutest little bakery! Went in on my birthday a... 2018-01-08 19:06:27
# ...                                                    ...                 ...
# 1199987  Food is OK, no cash, electronic receipt never ... 2017-07-01 20:22:16
# 1199988  Great meal!  The red fish special was amazing.... 2017-09-19 00:04:01
# 1199992  Service was good and attentive without being t... 2017-01-20 19:55:20
# 1199997  Baklava was the size of my thumb. Fast deliver... 2018-09-10 04:01:29
# 1199998  Personally I found this location to be excelle... 2018-06-06 23:36:24
#
# [678845 rows x 6 columns]

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/reviewYelp7.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Eliminar las columnas 'useful', 'funny' y 'cool'
df = df.drop(['useful', 'funny', 'cool'], axis=1)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Filtrar por la columna 'date' para mantener solo las entradas a partir de 2017
df = df[df['date'] >= '2017-01-01']

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review7.csv"

# Guardar el DataFrame resultante en un archivo CSV llamado "Review7.csv"
df.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame resultante usando display
display(df)
# Out:
#                       review_id                 user_id  \
# 2        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 7        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 12       EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 22       svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 27       mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 1190273  zHZ-A1qyKDEgyZMDaD--wg  _XVdmFWSgTN6YlojUxixTA
# 1190276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 1190277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 1190278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 1190279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  \
# 2        yPSejq3_erxo9zdVYTBnZA      5
# 7        7Y_BCrWzvzHyPtaLsacL7Q      4
# 12       DZYSb9amfB3EAh1IdwtbEA      3
# 22       MuQ-irulfi6V8N9Ka6XBHQ      5
# 27       q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 1190273  6WaI-IN8ql0xpEKlb4q8tg      5
# 1190276  2vLksaMmSEcGbjI5gywpZA      5
# 1190277  R1khUUxidqfaJmcpmGd4aw      4
# 1190278  Rr9kKArrMhSLVE9a53q-aA      5
# 1190279  VAeEXLbEcI9Emt9KGYq9aA      3
#
#                                                       text                date
# 2        This is the best Mexico food I ever had. I and... 2018-08-22 19:58:57
# 7        Outdoor enclosed garden. Very pretty but kind ... 2018-08-09 02:46:37
# 12       This is my first time eating at this location.... 2018-07-30 00:01:44
# 22       Update: We have been here several times since ... 2018-04-19 02:08:32
# 27       The avocado toast is to die for. I add the poa... 2017-12-07 15:06:14
# ...                                                    ...                 ...
# 1190273  We redesigned my moms dress and mad it complet... 2022-01-17 20:59:01
# 1190276  This spot offers a great, affordable east week... 2021-03-31 16:55:10
# 1190277  This Home Depot won me over when I needed to g... 2019-12-30 03:56:30
# 1190278  For when I'm feeling like ignoring my calorie-... 2022-01-19 18:59:27
# 1190279  Located in the 'Walking District' in Nashville... 2018-01-02 22:50:47
#
# [706842 rows x 6 columns]

# %% [markdown]
# # Se concatenan todos los archivos

# %%
import pandas as pd

# Lista de rutas a los archivos CSV a concatenar
rutas_csv = [
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review7.csv",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review6.csv",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review5.csv",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review4.csv",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review3.csv",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review2.csv",
    "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/Review1.csv"
]

# Lista para almacenar DataFrames de cada archivo CSV
dataframes = []

# Cargar y concatenar los archivos CSV
for ruta_csv in rutas_csv:
    df = pd.read_csv(ruta_csv)
    dataframes.append(df)

# Concatenar los DataFrames en uno solo
df_concatenado = pd.concat(dataframes, ignore_index=True)

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Guardar el DataFrame concatenado en un archivo CSV llamado "ReviewYelp.csv"
df_concatenado.to_csv(ruta_csv_resultante, index=False)

# Mostrar el DataFrame concatenado utilizando display
display(df_concatenado)
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 2        EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 3        svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 4        mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 4265989  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 4265990  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 4265991  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 4265992  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 4265993  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                     business_id  stars  \
# 0        yPSejq3_erxo9zdVYTBnZA      5
# 1        7Y_BCrWzvzHyPtaLsacL7Q      4
# 2        DZYSb9amfB3EAh1IdwtbEA      3
# 3        MuQ-irulfi6V8N9Ka6XBHQ      5
# 4        q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 4265989  c6qyEglw37vrDnUXabvWvw      5
# 4265990  cxupofYLq46bxBHpKyFwsQ      4
# 4265991  WVX0JKV9ZP-r9bz0A4xAVw      4
# 4265992  SoEnVtFQWEhBUBQXq9O5Ag      5
# 4265993  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                       text  \
# 0        This is the best Mexico food I ever had. I and...
# 1        Outdoor enclosed garden. Very pretty but kind ...
# 2        This is my first time eating at this location....
# 3        Update: We have been here several times since ...
# 4        The avocado toast is to die for. I add the poa...
# ...                                                    ...
# 4265989  Incredibly responsive, communicates well and e...
# 4265990  Stayed here the wknd of Labor Day/Decadence.  ...
# 4265991  Less crowded than Parksdale if you're craving ...
# 4265992  I love OG!!! We started going to Metazoa becau...
# 4265993  One of the best Szechwan restaurants you can f...
#
#                         date
# 0        2018-08-22 19:58:57
# 1        2018-08-09 02:46:37
# 2        2018-07-30 00:01:44
# 3        2018-04-19 02:08:32
# 4        2017-12-07 15:06:14
# ...                      ...
# 4265989  2018-05-08 23:59:01
# 4265990  2019-09-17 18:26:11
# 4265991  2020-01-27 14:19:10
# 4265992  2020-11-08 01:59:14
# 4265993  2021-04-13 04:34:15
#
# [4265994 rows x 6 columns]

# %% [markdown]
# # Buscamos el porcentaje de nulos de las columnas.

# %%
import pandas as pd

# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Calcular el porcentaje de valores nulos por columna
porcentaje_nulos_por_columna = (df.isnull().sum() / len(df)) * 100

print(porcentaje_nulos_por_columna)
# Out:
# review_id      0.000000
# user_id        0.000000
# business_id    0.000000
# stars          0.000000
# text           0.000234
# date           0.000000
# dtype: float64

# %% [markdown]
# # Convertimos la columna date a formato fecha

# %%
import pandas as pd

# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Convertir la columna 'date' a tipo datetime
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # Se crean las columnas anio, mes y día y se elimina date

# %%
df['anio'] = df['date'].dt.year

df['mes'] = df['date'].dt.month

df['dia'] = df['date'].dt.day

df = df.drop(['date'],axis=1)
df
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 2        EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 3        svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 4        mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 3838100  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 3838101  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 3838102  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 3838103  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 3838104  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                     business_id  stars  \
# 0        yPSejq3_erxo9zdVYTBnZA      5
# 1        7Y_BCrWzvzHyPtaLsacL7Q      4
# 2        DZYSb9amfB3EAh1IdwtbEA      3
# 3        MuQ-irulfi6V8N9Ka6XBHQ      5
# 4        q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 3838100  c6qyEglw37vrDnUXabvWvw      5
# 3838101  cxupofYLq46bxBHpKyFwsQ      4
# 3838102  WVX0JKV9ZP-r9bz0A4xAVw      4
# 3838103  SoEnVtFQWEhBUBQXq9O5Ag      5
# 3838104  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                       text  anio  mes  dia
# 0        this is the best mexico food i ever had. i and...  2018    8   22
# 1        outdoor enclosed garden. very pretty but kind ...  2018    8    9
# 2        this is my first time eating at this location....  2018    7   30
# 3        update: we have been here several times since ...  2018    4   19
# 4        the avocado toast is to die for. i add the poa...  2017   12    7
# ...                                                    ...   ...  ...  ...
# 3838100  incredibly responsive, communicates well and e...  2018    5    8
# 3838101  stayed here the wknd of labor day/decadence.  ...  2019    9   17
# 3838102  less crowded than parksdale if you're craving ...  2020    1   27
# 3838103  i love og!!! we started going to metazoa becau...  2020   11    8
# 3838104  one of the best szechwan restaurants you can f...  2021    4   13
#
# [3838105 rows x 8 columns]

# %%
# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Guardar el DataFrame concatenado en un archivo CSV llamado "ReviewYelp.csv"
df_concatenado.to_csv(ruta_csv_resultante, index=False)

df
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 2        EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 3        svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 4        mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 4265989  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 4265990  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 4265991  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 4265992  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 4265993  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                     business_id  stars  \
# 0        yPSejq3_erxo9zdVYTBnZA      5
# 1        7Y_BCrWzvzHyPtaLsacL7Q      4
# 2        DZYSb9amfB3EAh1IdwtbEA      3
# 3        MuQ-irulfi6V8N9Ka6XBHQ      5
# 4        q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 4265989  c6qyEglw37vrDnUXabvWvw      5
# 4265990  cxupofYLq46bxBHpKyFwsQ      4
# 4265991  WVX0JKV9ZP-r9bz0A4xAVw      4
# 4265992  SoEnVtFQWEhBUBQXq9O5Ag      5
# 4265993  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                       text  anio  mes  dia
# 0        This is the best Mexico food I ever had. I and...  2018    8   22
# 1        Outdoor enclosed garden. Very pretty but kind ...  2018    8    9
# 2        This is my first time eating at this location....  2018    7   30
# 3        Update: We have been here several times since ...  2018    4   19
# 4        The avocado toast is to die for. I add the poa...  2017   12    7
# ...                                                    ...   ...  ...  ...
# 4265989  Incredibly responsive, communicates well and e...  2018    5    8
# 4265990  Stayed here the wknd of Labor Day/Decadence.  ...  2019    9   17
# 4265991  Less crowded than Parksdale if you're craving ...  2020    1   27
# 4265992  I love OG!!! We started going to Metazoa becau...  2020   11    8
# 4265993  One of the best Szechwan restaurants you can f...  2021    4   13
#
# [4265994 rows x 8 columns]

# %% [markdown]
# # Se pasa a minuscula para la columna text y se quitan emojis.

# %% [markdown]
# # Función para quitar emojis

# %%
def remove_emojis(text):
    return demoji.replace(text, '')

# %%
def remove_emojis_2(text):
    if type(text) == str:
        return demoji.replace(text, '')
    else:
        return None

# %%
import pandas as pd
import numpy as np
import json
import datetime
import re #Expresiones regulares
import demoji 


# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)


df['text']= df['text'].apply(remove_emojis)
df['text']=df['text'].apply(lambda x: x.lower() if x is not None else '')
df
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 2        EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 3        svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 4        mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 4265989  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 4265990  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 4265991  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 4265992  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 4265993  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                     business_id  stars  \
# 0        yPSejq3_erxo9zdVYTBnZA      5
# 1        7Y_BCrWzvzHyPtaLsacL7Q      4
# 2        DZYSb9amfB3EAh1IdwtbEA      3
# 3        MuQ-irulfi6V8N9Ka6XBHQ      5
# 4        q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 4265989  c6qyEglw37vrDnUXabvWvw      5
# 4265990  cxupofYLq46bxBHpKyFwsQ      4
# 4265991  WVX0JKV9ZP-r9bz0A4xAVw      4
# 4265992  SoEnVtFQWEhBUBQXq9O5Ag      5
# 4265993  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                       text  \
# 0        this is the best mexico food i ever had. i and...
# 1        outdoor enclosed garden. very pretty but kind ...
# 2        this is my first time eating at this location....
# 3        update: we have been here several times since ...
# 4        the avocado toast is to die for. i add the poa...
# ...                                                    ...
# 4265989  incredibly responsive, communicates well and e...
# 4265990  stayed here the wknd of labor day/decadence.  ...
# 4265991  less crowded than parksdale if you're craving ...
# 4265992  i love og!!! we started going to metazoa becau...
# 4265993  one of the best szechwan restaurants you can f...
#
#                         date
# 0        2018-08-22 19:58:57
# 1        2018-08-09 02:46:37
# 2        2018-07-30 00:01:44
# 3        2018-04-19 02:08:32
# 4        2017-12-07 15:06:14
# ...                      ...
# 4265989  2018-05-08 23:59:01
# 4265990  2019-09-17 18:26:11
# 4265991  2020-01-27 14:19:10
# 4265992  2020-11-08 01:59:14
# 4265993  2021-04-13 04:34:15
#
# [4265994 rows x 6 columns]

# %% [markdown]
# # Se verifica si existen duplicados

# %%
df.duplicated().sum()
# Out:
# 427889

# %% [markdown]
# # Se eliminan los duplicados

# %%
df[df.duplicated(keep='first')]

df.drop_duplicates(inplace=True)

# Ruta al archivo CSV resultante
ruta_csv_resultante = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Guardar el DataFrame concatenado en un archivo CSV llamado "ReviewYelp.csv"
df.to_csv(ruta_csv_resultante, index=False)

df
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 2        EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 3        svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 4        mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 4265989  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 4265990  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 4265991  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 4265992  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 4265993  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                     business_id  stars  \
# 0        yPSejq3_erxo9zdVYTBnZA      5
# 1        7Y_BCrWzvzHyPtaLsacL7Q      4
# 2        DZYSb9amfB3EAh1IdwtbEA      3
# 3        MuQ-irulfi6V8N9Ka6XBHQ      5
# 4        q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 4265989  c6qyEglw37vrDnUXabvWvw      5
# 4265990  cxupofYLq46bxBHpKyFwsQ      4
# 4265991  WVX0JKV9ZP-r9bz0A4xAVw      4
# 4265992  SoEnVtFQWEhBUBQXq9O5Ag      5
# 4265993  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                       text  \
# 0        this is the best mexico food i ever had. i and...
# 1        outdoor enclosed garden. very pretty but kind ...
# 2        this is my first time eating at this location....
# 3        update: we have been here several times since ...
# 4        the avocado toast is to die for. i add the poa...
# ...                                                    ...
# 4265989  incredibly responsive, communicates well and e...
# 4265990  stayed here the wknd of labor day/decadence.  ...
# 4265991  less crowded than parksdale if you're craving ...
# 4265992  i love og!!! we started going to metazoa becau...
# 4265993  one of the best szechwan restaurants you can f...
#
#                         date
# 0        2018-08-22 19:58:57
# 1        2018-08-09 02:46:37
# 2        2018-07-30 00:01:44
# 3        2018-04-19 02:08:32
# 4        2017-12-07 15:06:14
# ...                      ...
# 4265989  2018-05-08 23:59:01
# 4265990  2019-09-17 18:26:11
# 4265991  2020-01-27 14:19:10
# 4265992  2020-11-08 01:59:14
# 4265993  2021-04-13 04:34:15
#
# [3838105 rows x 6 columns]

# %% [markdown]
# # Se verifica nuevamente

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        Vo5GCOXUQnu-6QIF1p4DhA  alxetHC3mXR2PtG8CeCN6Q
# 2        EXIAkcgUklM9AFWN8xdeSg  __FzScrH7kzHXdZpS_wjfA
# 3        svCl7Bq0ikDoNfIF5W2_5A  nZt_peXDet39VuLBD3nNXw
# 4        mvA0bX3WjYF_bArDS18qWg  kQpDOF6EQgjDz_S0aww9hA
# ...                         ...                     ...
# 4265989  XGOAD0UF2QdpyFN2Me0iRw  SrgEux62Uc4OrF8OEri0Mw
# 4265990  UM5_6U6-VkhjPgUBIlTbpQ  E-3SqqAxaKZxTzo0wp7V2Q
# 4265991  ITIq3k_wtfWrkZflMbXHwA  VigsAph76fP7pechJ743EA
# 4265992  7uBPnki8Jmoo5bjVZI2LZw  I-JKKX7PHHd_z9nNMkH6kg
# 4265993  3eFKgGCeQelZYF2PuutVGw  4PaGIGJ9pExEcODQjI4I8w
#
#                     business_id  stars  \
# 0        yPSejq3_erxo9zdVYTBnZA      5
# 1        7Y_BCrWzvzHyPtaLsacL7Q      4
# 2        DZYSb9amfB3EAh1IdwtbEA      3
# 3        MuQ-irulfi6V8N9Ka6XBHQ      5
# 4        q9Pupuw6Z2b8WaYK-MGt4g      5
# ...                         ...    ...
# 4265989  c6qyEglw37vrDnUXabvWvw      5
# 4265990  cxupofYLq46bxBHpKyFwsQ      4
# 4265991  WVX0JKV9ZP-r9bz0A4xAVw      4
# 4265992  SoEnVtFQWEhBUBQXq9O5Ag      5
# 4265993  A9rVxmIBtHZRvNhbBaGAWg      5
#
#                                                       text  \
# 0        this is the best mexico food i ever had. i and...
# 1        outdoor enclosed garden. very pretty but kind ...
# 2        this is my first time eating at this location....
# 3        update: we have been here several times since ...
# 4        the avocado toast is to die for. i add the poa...
# ...                                                    ...
# 4265989  incredibly responsive, communicates well and e...
# 4265990  stayed here the wknd of labor day/decadence.  ...
# 4265991  less crowded than parksdale if you're craving ...
# 4265992  i love og!!! we started going to metazoa becau...
# 4265993  one of the best szechwan restaurants you can f...
#
#                         date
# 0        2018-08-22 19:58:57
# 1        2018-08-09 02:46:37
# 2        2018-07-30 00:01:44
# 3        2018-04-19 02:08:32
# 4        2017-12-07 15:06:14
# ...                      ...
# 4265989  2018-05-08 23:59:01
# 4265990  2019-09-17 18:26:11
# 4265991  2020-01-27 14:19:10
# 4265992  2020-11-08 01:59:14
# 4265993  2021-04-13 04:34:15
#
# [3838105 rows x 6 columns]

# %% [markdown]
# # Se transforma para sólo dejar el texto en inglés.

# %%
import re

# %%
import pandas as pd
import re

# Ruta del archivo CSV
ruta_archivo = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_archivo)

# Aplicar re.sub solo si el valor es una cadena
df['text'] = df['text'].apply(lambda x: re.sub(r'\([^)]*\)|[\u4e00-\u9fff]', '', x) if isinstance(x, str) else x)

df['text'] = df['text'].apply(lambda x: x.split('\n\n\n')[0].strip() if isinstance(x, str) else x)

# %% [markdown]
# # Se explora el archivo Business.pkl.

# %%
import pandas as pd

# Ruta al archivo pickle
ruta_pkl = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/business.pkl"

# Cargar el archivo pickle en un DataFrame
df = pd.read_pickle(ruta_pkl)
df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2                  5255 E Broadway Blvd         Tucson   NaN       85711
# 3                           935 Race St   Philadelphia    CA       19107
# 4                         101 Walnut St     Green Lane    MO       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    IN     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    DE       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    AB       46250
# 150344                     2472 Troy Rd   Edwardsville    AB       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    TN       33572
#
#          latitude   longitude stars review_count  ... state postal_code  \
# 0       34.426679 -119.711197   5.0            7  ...   NaN         NaN
# 1       38.551126  -90.335695   3.0           15  ...   NaN         NaN
# 2       32.223236 -110.880452   3.5           22  ...   NaN         NaN
# 3       39.955505  -75.155564   4.0           80  ...   NaN         NaN
# 4       40.338183  -75.471659   4.5           13  ...   NaN         NaN
# ...           ...         ...   ...          ...  ...   ...         ...
# 150341  53.468419 -113.492054   3.0           13  ...   NaN         NaN
# 150342  36.115118  -86.766925   4.0            5  ...   NaN         NaN
# 150343  39.908707  -86.065088   3.5            8  ...   NaN         NaN
# 150344  38.782351  -89.950558   4.0           24  ...   NaN         NaN
# 150345  27.771002   -82.39491   4.5            9  ...   NaN         NaN
#
#        latitude longitude stars review_count is_open attributes categories  \
# 0           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 1           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 2           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 3           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 4           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# ...         ...       ...   ...          ...     ...        ...        ...
# 150341      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150342      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150343      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150344      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150345      NaN       NaN   NaN          NaN     NaN        NaN        NaN
#
#        hours
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 150341   NaN
# 150342   NaN
# 150343   NaN
# 150344   NaN
# 150345   NaN
#
# [150346 rows x 28 columns]

# %% [markdown]
# # Eliminamos las columnas duplicadas

# %%
import pandas as pd

# Ruta al archivo pickle
ruta_pkl = "C:/Users/Fede/Documents/Henry/Proyecto 3/Yelp/business.pkl"

# Cargar el archivo pickle en un DataFrame
df = pd.read_pickle(ruta_pkl)

# Eliminar columnas duplicadas manteniendo solo la primera aparición de cada una
df = df.loc[:, ~df.columns.duplicated(keep='first')]

# Guardar el DataFrame en un archivo pickle llamado 'business.pkl' (corrección en la ruta)
ruta_pkl_corregida = "C:/Users/Fede/Desktop/ETL/3er_Demo/business.pkl"
df.to_pickle(ruta_pkl_corregida, protocol=4)  # Usamos protocol=4 para garantizar la compatibilidad entre versiones

# Mostrar las columnas restantes
print(df.columns)
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# # Exploramos el porcentaje de nulos por columna.

# %%
import pandas as pd

# Ruta al archivo pickle
ruta_pkl = "C:/Users/Fede/Desktop/ETL/3er_Demo/business.pkl"

# Cargar el archivo pickle en un DataFrame
df = pd.read_pickle(ruta_pkl)

# Calcular el porcentaje de nulos en cada columna
porcentaje_nulos = (df.isnull().sum() / len(df)) * 100

# Crear un DataFrame con el porcentaje de nulos
porcentaje_nulos_df = pd.DataFrame({'Columna': porcentaje_nulos.index, 'Porcentaje de Nulos': porcentaje_nulos.values})

# Mostrar el DataFrame con el porcentaje de nulos
print(porcentaje_nulos_df)
# Out:
#          Columna  Porcentaje de Nulos
# 0    business_id             0.000000
# 1           name             0.000000
# 2        address             0.000000
# 3           city             0.000000
# 4          state             0.001995
# 5    postal_code             0.000000
# 6       latitude             0.000000
# 7      longitude             0.000000
# 8          stars             0.000000
# 9   review_count             0.000000
# 10       is_open             0.000000
# 11    attributes             9.141580
# 12    categories             0.068509
# 13         hours            15.446370

# %% [markdown]
# # Se eliminan las columnas innecesarias para el proyecto y se lo convierte a csv.

# %%
import pandas as pd

# Ruta al archivo pickle
ruta_pkl = "C:/Users/Fede/Desktop/ETL/3er_Demo/business.pkl"

# Cargar el archivo pickle en un DataFrame
df = pd.read_pickle(ruta_pkl)

# Lista de nombres de columnas a eliminar
columnas_a_eliminar = ["latitude", "longitude", "postal_code", "is_open"]

# Eliminar las columnas especificadas
df = df.drop(columns=columnas_a_eliminar)

# Guardar el DataFrame en un archivo CSV en la misma ruta
ruta_csv = ruta_pkl.replace(".pkl", ".csv")  # Cambiar la extensión del archivo
df.to_csv(ruta_csv, index=False)

# Mostrar las columnas restantes
print(df.columns)

df
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'stars',
#        'review_count', 'attributes', 'categories', 'hours'],
#       dtype='object')
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state stars  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN   5.0
# 1       87 Grasso Plaza Shopping Center         Affton   NaN   3.0
# 2                  5255 E Broadway Blvd         Tucson   NaN   3.5
# 3                           935 Race St   Philadelphia    CA   4.0
# 4                         101 Walnut St     Green Lane    MO   4.5
# ...                                 ...            ...   ...   ...
# 150341                3388 Gateway Blvd       Edmonton    IN   3.0
# 150342               2813 Bransford Ave      Nashville    DE   4.0
# 150343           6020 E 82nd St, Ste 46   Indianapolis    AB   3.5
# 150344                     2472 Troy Rd   Edwardsville    AB   4.0
# 150345            238 Apollo Beach Blvd   Apollo beach    TN   4.5
#
#        review_count                                         attributes  \
# 0                 7                      {'ByAppointmentOnly': 'True'}
# 1                15             {'BusinessAcceptsCreditCards': 'True'}
# 2                22  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3                80  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4                13  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...             ...                                                ...
# 150341           13  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342            5  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343            8  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344           24  {'BusinessParking': '{'garage': False, 'street...
# 150345            9  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                               None
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 10 columns]

# %% [markdown]
# # Concatenamos Business con Yelp en un nuevo csv.

# %%
import pandas as pd

# Rutas de los archivos CSV
ruta_csv1 = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewYelp.csv"
ruta_csv2 = "C:/Users/Fede/Desktop/ETL/3er_Demo/business.csv"

# Cargar los archivos CSV en DataFrames
df1 = pd.read_csv(ruta_csv1)
df2 = pd.read_csv(ruta_csv2)

# Concatenar DataFrames por la columna 'business_id'
df_concatenado = pd.merge(df1, df2, on='business_id', how='inner')

# Guardar el DataFrame concatenado en un archivo CSV llamado 'Yelp.csv'
ruta_csv_concatenado = "C:/Users/Fede/Desktop/ETL/3er_Demo/Yelp.csv"
df_concatenado.to_csv(ruta_csv_concatenado, index=False)

# Mostrar el DataFrame concatenado utilizando display
display(df_concatenado)
# Out:
#                       review_id                 user_id  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        SEymzQsU-rrAh75u8xVZ-Q  XkrdCao1nLstiiQl11yZtg
# 2        WO5VuakHx7EO8Tz3h4silQ  2-lD9rAZbsGzT1MLd3LC5g
# 3        gUF0ZZrQ279tJ2V0DzoMBw  2mDr-OsjP7L-pImFcErp8A
# 4        idhJtgTfWhDn7ONx88oyXQ  bvusPTKlJp5gkCW9iCG2iQ
# ...                         ...                     ...
# 3838100  5gyPDt6fsWQyegw87ZJ5HQ  a2-2nKbYPTDtgwvKd3JLrw
# 3838101  vYQiWqb4NWC3ka0rLoTxgg  T7RQKxz3PMX0g34yOp2_Qw
# 3838102  xpuTVnh-ktmRpdoGtSvNBw  f8pYnB1RbTgJ9okshVDbjQ
# 3838103  BXuZ0oUTp3reU9Yix-J0cw  kGndqtEN6qHA9ZLvBujOtA
# 3838104  ZcyxOguwLuuN0c2nbn0XrA  CoT2VXuqKbBb3e3cUINXTQ
#
#                     business_id  stars_x  \
# 0        yPSejq3_erxo9zdVYTBnZA        5
# 1        yPSejq3_erxo9zdVYTBnZA        5
# 2        yPSejq3_erxo9zdVYTBnZA        3
# 3        yPSejq3_erxo9zdVYTBnZA        5
# 4        yPSejq3_erxo9zdVYTBnZA        5
# ...                         ...      ...
# 3838100  15AxDnfjRdXoma781qDRuQ        1
# 3838101  IbdpXTUI56Jb5uCqUsKzhw        5
# 3838102  tgWxnsQ8XIFdGeOKWhz1uQ        5
# 3838103  fAACT0qzYnDIhuLFEk8FcA        4
# 3838104  aTrhRm2_bJ9glxOPw9WqZQ        5
#
#                                                       text  \
# 0        this is the best mexico food i ever had. i and...
# 1        always delicious. ordered the al pastor tacos ...
# 2        the food is not that good this restaurant gets...
# 3        good mexican food in santa barbara! you order ...
# 4        excellent restaurant best mexican restaurant i...
# ...                                                    ...
# 3838100  unprofessional.  i called several days ago and...
# 3838101  great place to bull shit and shoot some pool. ...
# 3838102  went for a nail appointment, all ladies were v...
# 3838103  i typically don't review chain stores, but the...
# 3838104  this store is beautiful. a little on the highe...
#
#                         date                       name  \
# 0        2018-08-22 19:58:57                 Los Agaves
# 1        2018-07-03 20:25:36                 Los Agaves
# 2        2017-10-23 13:11:45                 Los Agaves
# 3        2018-01-25 11:06:00                 Los Agaves
# 4        2018-05-16 18:32:55                 Los Agaves
# ...                      ...                        ...
# 3838100  2017-08-07 15:58:13   Roberts Mobile Mechanics
# 3838101  2018-12-16 20:21:46         Manny & Phil's Pub
# 3838102  2018-05-18 15:24:27             Nails-Go-Round
# 3838103  2021-08-01 02:17:36                     Buckle
# 3838104  2020-02-08 00:28:07  Ashley Austin Accessories
#
#                            address            city state  stars_y  \
# 0                  600 N Milpas St   Santa Barbara    AZ      4.5
# 1                  600 N Milpas St   Santa Barbara    AZ      4.5
# 2                  600 N Milpas St   Santa Barbara    AZ      4.5
# 3                  600 N Milpas St   Santa Barbara    AZ      4.5
# 4                  600 N Milpas St   Santa Barbara    AZ      4.5
# ...                            ...             ...   ...      ...
# 3838100             504 Raymond St       Nashville    LA      3.5
# 3838101              1801 S 4th St    Philadelphia    AZ      4.0
# 3838102             651 W Roger Rd          Tucson    IN      3.0
# 3838103  26 W County Ctr, Ste 1080       Des Peres    PA      5.0
# 3838104             106 W State St  Kennett Square    LA      5.0
#
#          review_count                                         attributes  \
# 0                3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 1                3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 2                3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 3                3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 4                3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# ...               ...                                                ...
# 3838100            11  {'BusinessAcceptsCreditCards': 'False', 'WiFi'...
# 3838101             8  {'RestaurantsPriceRange2': '1', 'NoiseLevel': ...
# 3838102            10  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 3838103             5  {'BikeParking': 'False', 'BusinessParking': "{...
# 3838104             6  {'BusinessParking': "{'garage': False, 'street...
#
#                                                 categories  \
# 0                                     Mexican, Restaurants
# 1                                     Mexican, Restaurants
# 2                                     Mexican, Restaurants
# 3                                     Mexican, Restaurants
# 4                                     Mexican, Restaurants
# ...                                                    ...
# 3838100  Auto Repair, Auto Parts & Supplies, Automotive...
# 3838101                         Dive Bars, Nightlife, Bars
# 3838102                         Nail Salons, Beauty & Spas
# 3838103  Fashion, Shopping, Accessories, Men's Clothing...
# 3838104  Jewelry, Accessories, Shopping, Fashion, Shoe ...
#
#                                                      hours
# 0        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 1        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 3        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# ...                                                    ...
# 3838100  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# 3838101  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
# 3838102  {'Tuesday': '10:0-18:0', 'Wednesday': '10:0-18...
# 3838103  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 3838104  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
#
# [3838105 rows x 15 columns]

# %% [markdown]
# # Cambiamos el nombre de las columnas para que coincidan con las de GoogleMaps

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv_original = "C:/Users/Fede/Desktop/ETL/3er_Demo/Yelp.csv"

# Leer el archivo CSV original en un DataFrame
df = pd.read_csv(ruta_csv_original)

# Cambiar los nombres de las columnas
nuevos_nombres = {
    'user_id': 'Usuario',
    'stars_x': 'Estrellas_Negocio',
    'text': 'Review',
    'name': 'Negocio',
    'address': 'Direccion_Negocio',
    'state': 'Estado',
    'stars_y': 'Rating_Usuario',
    'review_count': 'Numero_reviews',
    'categories': 'Clasificacion Negocio',
    'date': 'time'
    'city': 'Ciudad'
    
}

# Reorganizar las columnas y cambiar los nombres
df = df.rename(columns=nuevos_nombres)

# Guardar el DataFrame modificado en un archivo CSV llamado 'Yelp2.csv'
ruta_csv_modificado = "C:/Users/Fede/Desktop/ETL/3er_Demo/Yelp2.csv"
df.to_csv(ruta_csv_modificado, index=False)

# Mostrar el DataFrame modificado utilizando display
display(df)
# Out:
#                       review_id                 Usuario  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        SEymzQsU-rrAh75u8xVZ-Q  XkrdCao1nLstiiQl11yZtg
# 2        WO5VuakHx7EO8Tz3h4silQ  2-lD9rAZbsGzT1MLd3LC5g
# 3        gUF0ZZrQ279tJ2V0DzoMBw  2mDr-OsjP7L-pImFcErp8A
# 4        idhJtgTfWhDn7ONx88oyXQ  bvusPTKlJp5gkCW9iCG2iQ
# ...                         ...                     ...
# 3838100  5gyPDt6fsWQyegw87ZJ5HQ  a2-2nKbYPTDtgwvKd3JLrw
# 3838101  vYQiWqb4NWC3ka0rLoTxgg  T7RQKxz3PMX0g34yOp2_Qw
# 3838102  xpuTVnh-ktmRpdoGtSvNBw  f8pYnB1RbTgJ9okshVDbjQ
# 3838103  BXuZ0oUTp3reU9Yix-J0cw  kGndqtEN6qHA9ZLvBujOtA
# 3838104  ZcyxOguwLuuN0c2nbn0XrA  CoT2VXuqKbBb3e3cUINXTQ
#
#                     business_id  Estrellas_Negocio  \
# 0        yPSejq3_erxo9zdVYTBnZA                  5
# 1        yPSejq3_erxo9zdVYTBnZA                  5
# 2        yPSejq3_erxo9zdVYTBnZA                  3
# 3        yPSejq3_erxo9zdVYTBnZA                  5
# 4        yPSejq3_erxo9zdVYTBnZA                  5
# ...                         ...                ...
# 3838100  15AxDnfjRdXoma781qDRuQ                  1
# 3838101  IbdpXTUI56Jb5uCqUsKzhw                  5
# 3838102  tgWxnsQ8XIFdGeOKWhz1uQ                  5
# 3838103  fAACT0qzYnDIhuLFEk8FcA                  4
# 3838104  aTrhRm2_bJ9glxOPw9WqZQ                  5
#
#                                                     Review  \
# 0        this is the best mexico food i ever had. i and...
# 1        always delicious. ordered the al pastor tacos ...
# 2        the food is not that good this restaurant gets...
# 3        good mexican food in santa barbara! you order ...
# 4        excellent restaurant best mexican restaurant i...
# ...                                                    ...
# 3838100  unprofessional.  i called several days ago and...
# 3838101  great place to bull shit and shoot some pool. ...
# 3838102  went for a nail appointment, all ladies were v...
# 3838103  i typically don't review chain stores, but the...
# 3838104  this store is beautiful. a little on the highe...
#
#                         time                    Negocio  \
# 0        2018-08-22 19:58:57                 Los Agaves
# 1        2018-07-03 20:25:36                 Los Agaves
# 2        2017-10-23 13:11:45                 Los Agaves
# 3        2018-01-25 11:06:00                 Los Agaves
# 4        2018-05-16 18:32:55                 Los Agaves
# ...                      ...                        ...
# 3838100  2017-08-07 15:58:13   Roberts Mobile Mechanics
# 3838101  2018-12-16 20:21:46         Manny & Phil's Pub
# 3838102  2018-05-18 15:24:27             Nails-Go-Round
# 3838103  2021-08-01 02:17:36                     Buckle
# 3838104  2020-02-08 00:28:07  Ashley Austin Accessories
#
#                  Direccion_Negocio            city Estado  Estrellas_Review  \
# 0                  600 N Milpas St   Santa Barbara     AZ               4.5
# 1                  600 N Milpas St   Santa Barbara     AZ               4.5
# 2                  600 N Milpas St   Santa Barbara     AZ               4.5
# 3                  600 N Milpas St   Santa Barbara     AZ               4.5
# 4                  600 N Milpas St   Santa Barbara     AZ               4.5
# ...                            ...             ...    ...               ...
# 3838100             504 Raymond St       Nashville     LA               3.5
# 3838101              1801 S 4th St    Philadelphia     AZ               4.0
# 3838102             651 W Roger Rd          Tucson     IN               3.0
# 3838103  26 W County Ctr, Ste 1080       Des Peres     PA               5.0
# 3838104             106 W State St  Kennett Square     LA               5.0
#
#          Numero_reviews                                         attributes  \
# 0                  3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 1                  3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 2                  3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 3                  3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 4                  3834  {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# ...                 ...                                                ...
# 3838100              11  {'BusinessAcceptsCreditCards': 'False', 'WiFi'...
# 3838101               8  {'RestaurantsPriceRange2': '1', 'NoiseLevel': ...
# 3838102              10  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 3838103               5  {'BikeParking': 'False', 'BusinessParking': "{...
# 3838104               6  {'BusinessParking': "{'garage': False, 'street...
#
#                                      Clasificacion Negocio  \
# 0                                     Mexican, Restaurants
# 1                                     Mexican, Restaurants
# 2                                     Mexican, Restaurants
# 3                                     Mexican, Restaurants
# 4                                     Mexican, Restaurants
# ...                                                    ...
# 3838100  Auto Repair, Auto Parts & Supplies, Automotive...
# 3838101                         Dive Bars, Nightlife, Bars
# 3838102                         Nail Salons, Beauty & Spas
# 3838103  Fashion, Shopping, Accessories, Men's Clothing...
# 3838104  Jewelry, Accessories, Shopping, Fashion, Shoe ...
#
#                                                      hours
# 0        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 1        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 3        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# ...                                                    ...
# 3838100  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# 3838101  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...
# 3838102  {'Tuesday': '10:0-18:0', 'Wednesday': '10:0-18...
# 3838103  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 3838104  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
#
# [3838105 rows x 15 columns]

# %% [markdown]
# # Cambiamos el formato de la columna time a datetime.

# %%
import pandas as pd

# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/Yelp2.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Convertir la columna time a formato datetime sin especificar la unidad
df['time'] = pd.to_datetime(df['time'])

# Se crean las columnas anio, mes y día
df['anio'] = df['time'].dt.year
df['mes'] = df['time'].dt.month
df['dia'] = df['time'].dt.day

# Eliminar la columna 'time'
df = df.drop(columns=['time'])

# Ruta al nuevo archivo CSV donde se guardará el DataFrame resultante
ruta_nuevo_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewsFecha.csv"

# Guardar el DataFrame resultante en un nuevo archivo CSV
df.to_csv(ruta_nuevo_csv, index=False)

# Mostrar el DataFrame resultante
display(df)
# Out:
#                       review_id                 Usuario  \
# 0        J-GHkqsrHy3pztjbaqUBLg  qLsS_1YJTypJg_JcCSKeaw
# 1        SEymzQsU-rrAh75u8xVZ-Q  XkrdCao1nLstiiQl11yZtg
# 2        WO5VuakHx7EO8Tz3h4silQ  2-lD9rAZbsGzT1MLd3LC5g
# 3        gUF0ZZrQ279tJ2V0DzoMBw  2mDr-OsjP7L-pImFcErp8A
# 4        idhJtgTfWhDn7ONx88oyXQ  bvusPTKlJp5gkCW9iCG2iQ
# ...                         ...                     ...
# 3838100  5gyPDt6fsWQyegw87ZJ5HQ  a2-2nKbYPTDtgwvKd3JLrw
# 3838101  vYQiWqb4NWC3ka0rLoTxgg  T7RQKxz3PMX0g34yOp2_Qw
# 3838102  xpuTVnh-ktmRpdoGtSvNBw  f8pYnB1RbTgJ9okshVDbjQ
# 3838103  BXuZ0oUTp3reU9Yix-J0cw  kGndqtEN6qHA9ZLvBujOtA
# 3838104  ZcyxOguwLuuN0c2nbn0XrA  CoT2VXuqKbBb3e3cUINXTQ
#
#                     business_id  Estrellas_Negocio  \
# 0        yPSejq3_erxo9zdVYTBnZA                  5
# 1        yPSejq3_erxo9zdVYTBnZA                  5
# 2        yPSejq3_erxo9zdVYTBnZA                  3
# 3        yPSejq3_erxo9zdVYTBnZA                  5
# 4        yPSejq3_erxo9zdVYTBnZA                  5
# ...                         ...                ...
# 3838100  15AxDnfjRdXoma781qDRuQ                  1
# 3838101  IbdpXTUI56Jb5uCqUsKzhw                  5
# 3838102  tgWxnsQ8XIFdGeOKWhz1uQ                  5
# 3838103  fAACT0qzYnDIhuLFEk8FcA                  4
# 3838104  aTrhRm2_bJ9glxOPw9WqZQ                  5
#
#                                                     Review  \
# 0        this is the best mexico food i ever had. i and...
# 1        always delicious. ordered the al pastor tacos ...
# 2        the food is not that good this restaurant gets...
# 3        good mexican food in santa barbara! you order ...
# 4        excellent restaurant best mexican restaurant i...
# ...                                                    ...
# 3838100  unprofessional.  i called several days ago and...
# 3838101  great place to bull shit and shoot some pool. ...
# 3838102  went for a nail appointment, all ladies were v...
# 3838103  i typically don't review chain stores, but the...
# 3838104  this store is beautiful. a little on the highe...
#
#                            Negocio          Direccion_Negocio            city  \
# 0                       Los Agaves            600 N Milpas St   Santa Barbara
# 1                       Los Agaves            600 N Milpas St   Santa Barbara
# 2                       Los Agaves            600 N Milpas St   Santa Barbara
# 3                       Los Agaves            600 N Milpas St   Santa Barbara
# 4                       Los Agaves            600 N Milpas St   Santa Barbara
# ...                            ...                        ...             ...
# 3838100   Roberts Mobile Mechanics             504 Raymond St       Nashville
# 3838101         Manny & Phil's Pub              1801 S 4th St    Philadelphia
# 3838102             Nails-Go-Round             651 W Roger Rd          Tucson
# 3838103                     Buckle  26 W County Ctr, Ste 1080       Des Peres
# 3838104  Ashley Austin Accessories             106 W State St  Kennett Square
#
#         Estado  Estrellas_Review  Numero_reviews  \
# 0           AZ               4.5            3834
# 1           AZ               4.5            3834
# 2           AZ               4.5            3834
# 3           AZ               4.5            3834
# 4           AZ               4.5            3834
# ...        ...               ...             ...
# 3838100     LA               3.5              11
# 3838101     AZ               4.0               8
# 3838102     IN               3.0              10
# 3838103     PA               5.0               5
# 3838104     LA               5.0               6
#
#                                                 attributes  \
# 0        {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 1        {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 2        {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 3        {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# 4        {'WiFi': "u'no'", 'RestaurantsTakeOut': 'True'...
# ...                                                    ...
# 3838100  {'BusinessAcceptsCreditCards': 'False', 'WiFi'...
# 3838101  {'RestaurantsPriceRange2': '1', 'NoiseLevel': ...
# 3838102  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 3838103  {'BikeParking': 'False', 'BusinessParking': "{...
# 3838104  {'BusinessParking': "{'garage': False, 'street...
#
#                                      Clasificacion Negocio  \
# 0                                     Mexican, Restaurants
# 1                                     Mexican, Restaurants
# 2                                     Mexican, Restaurants
# 3                                     Mexican, Restaurants
# 4                                     Mexican, Restaurants
# ...                                                    ...
# 3838100  Auto Repair, Auto Parts & Supplies, Automotive...
# 3838101                         Dive Bars, Nightlife, Bars
# 3838102                         Nail Salons, Beauty & Spas
# 3838103  Fashion, Shopping, Accessories, Men's Clothing...
# 3838104  Jewelry, Accessories, Shopping, Fashion, Shoe ...
#
#                                                      hours  anio  mes  dia
# 0        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018    8   22
# 1        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018    7    3
# 2        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017   10   23
# 3        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018    1   25
# 4        {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018    5   16
# ...                                                    ...   ...  ...  ...
# 3838100  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...  2017    8    7
# 3838101  {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...  2018   12   16
# 3838102  {'Tuesday': '10:0-18:0', 'Wednesday': '10:0-18...  2018    5   18
# 3838103  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...  2021    8    1
# 3838104  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...  2020    2    8
#
# [3838105 rows x 17 columns]

# %% [markdown]
# # Filtramos el DataFrame para obtener solo los negocios que pertenecen a la categoría restaurante.

# %%
import pandas as pd

# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewsFecha.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Filtrar el DataFrame por la categoría "Restaurante" en la columna "Clasificacion Negocio"
restaurantes_df = df[df['Clasificacion Negocio'] == 'Restaurants']

# Ruta al nuevo archivo CSV donde se guardará el DataFrame resultante
ruta_nuevo_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/YelpRestaurantes.csv"

# Guardar el DataFrame resultante en un nuevo archivo CSV

restaurantes_df.to_csv(ruta_nuevo_csv, index=False)

# Mostrar el DataFrame usando display
display(restaurantes_df)
# Out:
#                       review_id                 Usuario  \
# 253477   RPRbT9XuRtu-mFohs4HY1g  owaqho_ouQZNw7ZJte9gGA
# 253478   xjEWqMDYSreOl0SJiE3GJA  1ly0lMx7J2paDoiAWFltrw
# 253479   3U1WTp8A7U0ER5Za849vzQ  O0enDRwITAuQUa2iSqJJSw
# 253480   tAvIe_TOgWHlyeEcrSUOAg  jEcSGHkE31zEGt7p_8Mbkw
# 253481   5dGWXNXiR3tlDm-m-zV8Nw  FlXBpK_YZxLo27jcMdII1w
# ...                         ...                     ...
# 3801080  7xSr_Roh3y1bE7Q2QxYXHA  xcGPD8pdfyugcZ8SskvP1Q
# 3801081  F2nXmqin_RZMTEb38s8XoQ  zOZR3F-fLi9oP5_PHFlqeQ
# 3826366  T9Qnb47rHR_EKaQphhE7-g  v-4N19cAM0ah-JvUtWWF-Q
# 3826367  PIohTNhbEVEzUkPwrRAM2A  NFIueKWChUE1t5IIxl-RXw
# 3826499  mKAJMc0AdTrV03OjFcXeqw  rDoT-MgxGRiYqCmi0bG10g
#
#                     business_id  Estrellas_Negocio  \
# 253477   YinVjl_e8croGmeUK8hRkA                  5
# 253478   YinVjl_e8croGmeUK8hRkA                  5
# 253479   YinVjl_e8croGmeUK8hRkA                  4
# 253480   YinVjl_e8croGmeUK8hRkA                  5
# 253481   YinVjl_e8croGmeUK8hRkA                  5
# ...                         ...                ...
# 3801080  mFE9V6LPpsDRUQLEBsBRRA                  2
# 3801081  mFE9V6LPpsDRUQLEBsBRRA                  2
# 3826366  dOwN9-8QD4xwErNEMU_dMA                  1
# 3826367  dOwN9-8QD4xwErNEMU_dMA                  3
# 3826499  fLZ8IpBPsDjFzl7zuXRZ9w                  5
#
#                                                     Review  \
# 253477   friendly neighborhood bar with great bar food ...
# 253478   food is great!!!! customer service is top notc...
# 253479   great atmosphere!!!! clean, reasonable prices ...
# 253480   a great corner bar! cheers is the type of plac...
# 253481   great little neighborhood spot for a shot and ...
# ...                                                    ...
# 3801080  i picked up wings for a friend. i was charged ...
# 3801081  back in the day, pearl of east was the spot to...
# 3826366  la dueña and head cook are fantastic.  the pan...
# 3826367  waterside cafe is one of the places in which i...
# 3826499  this is the best donair i have ever had, maybe...
#
#                      Negocio                Direccion_Negocio          city  \
# 253477           Cheers Cafe           2601 E Westmoreland St  Philadelphia
# 253478           Cheers Cafe           2601 E Westmoreland St  Philadelphia
# 253479           Cheers Cafe           2601 E Westmoreland St  Philadelphia
# 253480           Cheers Cafe           2601 E Westmoreland St  Philadelphia
# 253481           Cheers Cafe           2601 E Westmoreland St  Philadelphia
# ...                      ...                              ...           ...
# 3801080        Pearl of East                2049 W Oregon Ave  Philadelphia
# 3801081        Pearl of East                2049 W Oregon Ave  Philadelphia
# 3826366       Waterside Cafe  4925 Independence Pkwy, Ste 130         Tampa
# 3826367       Waterside Cafe  4925 Independence Pkwy, Ste 130         Tampa
# 3826499  Zachs Famous Donair                   7609 38 Ave NW      Edmonton
#
#         Estado  Estrellas_Review  Numero_reviews  \
# 253477      CA               5.0               6
# 253478      CA               5.0               6
# 253479      CA               5.0               6
# 253480      CA               5.0               6
# 253481      CA               5.0               6
# ...        ...               ...             ...
# 3801080     IN               3.0              17
# 3801081     IN               3.0              17
# 3826366     IL               2.5               5
# 3826367     IL               2.5               5
# 3826499     FL               4.5               7
#
#                                                 attributes  \
# 253477   {'GoodForMeal': "{'dessert': False, 'latenight...
# 253478   {'GoodForMeal': "{'dessert': False, 'latenight...
# 253479   {'GoodForMeal': "{'dessert': False, 'latenight...
# 253480   {'GoodForMeal': "{'dessert': False, 'latenight...
# 253481   {'GoodForMeal': "{'dessert': False, 'latenight...
# ...                                                    ...
# 3801080  {'RestaurantsGoodForGroups': 'False', 'Busines...
# 3801081  {'RestaurantsGoodForGroups': 'False', 'Busines...
# 3826366  {'Ambience': "{'romantic': False, 'intimate': ...
# 3826367  {'Ambience': "{'romantic': False, 'intimate': ...
# 3826499  {'RestaurantsAttire': "u'casual'", 'Restaurant...
#
#         Clasificacion Negocio  \
# 253477            Restaurants
# 253478            Restaurants
# 253479            Restaurants
# 253480            Restaurants
# 253481            Restaurants
# ...                       ...
# 3801080           Restaurants
# 3801081           Restaurants
# 3826366           Restaurants
# 3826367           Restaurants
# 3826499           Restaurants
#
#                                                      hours  anio  mes  dia
# 253477                                                 NaN  2017   10   21
# 253478                                                 NaN  2020    3   27
# 253479                                                 NaN  2017    8   20
# 253480                                                 NaN  2019    7    6
# 253481                                                 NaN  2018    6   10
# ...                                                    ...   ...  ...  ...
# 3801080  {'Monday': '10:30-22:30', 'Tuesday': '10:30-22...  2021    1   23
# 3801081  {'Monday': '10:30-22:30', 'Tuesday': '10:30-22...  2019    3   12
# 3826366  {'Friday': '6:30-11:0', 'Saturday': '6:30-11:0...  2018    8   16
# 3826367  {'Friday': '6:30-11:0', 'Saturday': '6:30-11:0...  2018    9   20
# 3826499                                                NaN  2017    2    4
#
# [311 rows x 17 columns]

# %% [markdown]
# # Revisamos el tipo de columnas.

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado 'df'
# Por ejemplo, df = pd.read_csv('archivo.csv')

# Mostrar los tipos de columnas
tipos_de_columnas = restaurantes_df.dtypes

# Imprimir los tipos de columnas
print(tipos_de_columnas)
# Out:
# review_id                 object
# Usuario                   object
# business_id               object
# Estrellas_Negocio          int64
# Review                    object
# Negocio                   object
# Direccion_Negocio         object
# city                      object
# Estado                    object
# Estrellas_Review         float64
# Numero_reviews             int64
# attributes                object
# Clasificacion Negocio     object
# hours                     object
# anio                       int64
# mes                        int64
# dia                        int64
# dtype: object

# %% [markdown]
# # Filtramos el DataFrame por los Estados que vamos a utilizar para el análisis.

# %%
import pandas as pd

# Ruta al archivo CSV
archivo_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/ReviewsFecha.csv"

# Carga el archivo CSV en un DataFrame
data = pd.read_csv(archivo_csv)

# Lista de estados que deseas filtrar en formato de dos letras
estados_a_filtrar = ["NY", "CO", "CA", "TX", "GA"]

# Filtra las filas que pertenecen a los estados especificados
resultados_filtrados = data[data['Estado'].isin(estados_a_filtrar)]

display (resultados_filtrados)

# Si deseas guardar los resultados en un nuevo archivo CSV
resultados_filtrados.to_csv("C:/Users/Fede/Desktop/ETL/3er_Demo/YelpEstados.csv", index=False)
# Out:
#                       review_id                 Usuario  \
# 8085     clU5NAEaZvE_h1gqDMoeWw  o9J7icpvUVMhqfv0NIcdtg
# 8086     j_x39aO3QCrfBR_fHoJfvA  JW3s9ywVjPb_TJg_WjyT6A
# 8087     bixSl9zMcMjDpcaum1R4aQ  Ild9wQHEoIz1elQw-v2rVw
# 8088     nTE_fSNlvBNNDbAkrrmdUA  -KwHzuuEOw7_VdiJEwQLpg
# 8089     w5AMuRbBCWjxKRejKMKLxw  1Hwgfa-yHk2mUePYxI6NkA
# ...                         ...                     ...
# 3837833  Y8xmRKiupPe3AlbGW_MjUg  CcYXqx_6WoGZjEsSccKjLA
# 3837834  h1FgLZH6yKndf_0Mq5Yz0A  i05VU6YWiPqimBXH3f-Nvw
# 3838037  RrKFR0tmgEZNEYcBtfDSTA  0RNdKZMkBbj4Ek17u1Q1ZA
# 3838038  HPdNzmkum0tCi-EfMifC6g  3c-LhcR4Pb0UBU7XQd1ntg
# 3838066  zrLyIQMH3iXu_38dT-YBSw  cJg5C9tslHaCj591OzY5bQ
#
#                     business_id  Estrellas_Negocio  \
# 8085     rdC1Glqw0hfT7eEddYWsfQ                  3
# 8086     rdC1Glqw0hfT7eEddYWsfQ                  5
# 8087     rdC1Glqw0hfT7eEddYWsfQ                  2
# 8088     rdC1Glqw0hfT7eEddYWsfQ                  4
# 8089     rdC1Glqw0hfT7eEddYWsfQ                  1
# ...                         ...                ...
# 3837833  iipnazeY9eoANJ37l5fKwA                  5
# 3837834  iipnazeY9eoANJ37l5fKwA                  5
# 3838037  yJ9FTZHLZRZL3voM12vDtQ                  5
# 3838038  yJ9FTZHLZRZL3voM12vDtQ                  5
# 3838066  vmFyWIz_goMNO7a2vpraLw                  5
#
#                                                     Review  \
# 8085     sonny's bbq is one of my favorite restaurants ...
# 8086     love this place \n\nwish there was one close t...
# 8087     really dark, no atmosphere to speak of.  food ...
# 8088     love this place. i'm in wc at least 4-5 times ...
# 8089     this evening i stopped by this sonny's on my w...
# ...                                                    ...
# 3837833  i went to have a mug packaged and shipped, and...
# 3837834  i stopped in to ship a box to california, wher...
# 3838037  this food was delicious!! ordered: beef & broc...
# 3838038  this place is legit. no f cookie but i can ove...
# 3838066  as advertised- a positive experience and thoro...
#
#                      Negocio          Direccion_Negocio           city Estado  \
# 8085             Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel     CA
# 8086             Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel     CA
# 8087             Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel     CA
# 8088             Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel     CA
# 8089             Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel     CA
# ...                      ...                        ...            ...    ...
# 3837833     Post Pack & Ship               637 W Hwy 50       O'Fallon     CA
# 3837834     Post Pack & Ship               637 W Hwy 50       O'Fallon     CA
# 3838037      Chinese Express       311 De Baliviere Ave    Saint Louis     CA
# 3838038      Chinese Express       311 De Baliviere Ave    Saint Louis     CA
# 3838066  Plainfield Eye Care             900 Edwards Dr     Plainfield     CA
#
#          Estrellas_Review  Numero_reviews  \
# 8085                  3.0              82
# 8086                  3.0              82
# 8087                  3.0              82
# 8088                  3.0              82
# 8089                  3.0              82
# ...                   ...             ...
# 3837833               5.0               9
# 3837834               5.0               9
# 3838037               3.5               7
# 3838038               3.5               7
# 3838066               4.5              10
#
#                                                 attributes  \
# 8085     {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 8086     {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 8087     {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 8088     {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 8089     {'NoiseLevel': "'average'", 'Caters': 'True', ...
# ...                                                    ...
# 3837833                                                NaN
# 3837834                                                NaN
# 3838037  {'RestaurantsPriceRange2': '1', 'GoodForKids':...
# 3838038  {'RestaurantsPriceRange2': '1', 'GoodForKids':...
# 3838066  {'ByAppointmentOnly': 'True', 'BusinessParking...
#
#                                      Clasificacion Negocio  \
# 8085     Barbeque, Event Planning & Services, Restauran...
# 8086     Barbeque, Event Planning & Services, Restauran...
# 8087     Barbeque, Event Planning & Services, Restauran...
# 8088     Barbeque, Event Planning & Services, Restauran...
# 8089     Barbeque, Event Planning & Services, Restauran...
# ...                                                    ...
# 3837833  Packing Services, Shipping Centers, Local Serv...
# 3837834  Packing Services, Shipping Centers, Local Serv...
# 3838037                               Restaurants, Chinese
# 3838038                               Restaurants, Chinese
# 3838066  Optometrists, Shopping, Medical Supplies, Doct...
#
#                                                      hours  anio  mes  dia
# 8085     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017    4    2
# 8086     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017    5   21
# 8087     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017    3   14
# 8088     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018   11   25
# 8089     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018   11    3
# ...                                                    ...   ...  ...  ...
# 3837833                                                NaN  2017    5   17
# 3837834                                                NaN  2018    6   25
# 3838037  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  2018    1   27
# 3838038  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  2018   10    9
# 3838066  {'Monday': '8:0-19:0', 'Tuesday': '7:30-19:0',...  2021    7   13
#
# [127405 rows x 17 columns]

# %% [markdown]
# # Realizamos la sustitución de los códigos de estado al nombre completo.

# %%
import pandas as pd

# Ruta al archivo CSV
archivo_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/YelpEstados.csv"

# Carga el archivo CSV en un DataFrame
data = pd.read_csv(archivo_csv)

# Mapea los códigos de estado a los nombres completos
mapeo_estados = {
    "CA": "California",
    "NY": "New York",
    "CO": "Colorado",
    "TX": "Texas",
    "GA": "Georgia"
}

# Realiza la sustitución en la columna "Estado"
data['Estado'] = data['Estado'].map(mapeo_estados)

# Guarda los resultados en un nuevo archivo CSV
data.to_csv("C:/Users/Fede/Desktop/ETL/3er_Demo/YelpEstados_Nombres.csv", index=False)

# %%
data
# Out:
#                      review_id                 Usuario  \
# 0       clU5NAEaZvE_h1gqDMoeWw  o9J7icpvUVMhqfv0NIcdtg
# 1       j_x39aO3QCrfBR_fHoJfvA  JW3s9ywVjPb_TJg_WjyT6A
# 2       bixSl9zMcMjDpcaum1R4aQ  Ild9wQHEoIz1elQw-v2rVw
# 3       nTE_fSNlvBNNDbAkrrmdUA  -KwHzuuEOw7_VdiJEwQLpg
# 4       w5AMuRbBCWjxKRejKMKLxw  1Hwgfa-yHk2mUePYxI6NkA
# ...                        ...                     ...
# 127400  Y8xmRKiupPe3AlbGW_MjUg  CcYXqx_6WoGZjEsSccKjLA
# 127401  h1FgLZH6yKndf_0Mq5Yz0A  i05VU6YWiPqimBXH3f-Nvw
# 127402  RrKFR0tmgEZNEYcBtfDSTA  0RNdKZMkBbj4Ek17u1Q1ZA
# 127403  HPdNzmkum0tCi-EfMifC6g  3c-LhcR4Pb0UBU7XQd1ntg
# 127404  zrLyIQMH3iXu_38dT-YBSw  cJg5C9tslHaCj591OzY5bQ
#
#                    business_id  Estrellas_Negocio  \
# 0       rdC1Glqw0hfT7eEddYWsfQ                  3
# 1       rdC1Glqw0hfT7eEddYWsfQ                  5
# 2       rdC1Glqw0hfT7eEddYWsfQ                  2
# 3       rdC1Glqw0hfT7eEddYWsfQ                  4
# 4       rdC1Glqw0hfT7eEddYWsfQ                  1
# ...                        ...                ...
# 127400  iipnazeY9eoANJ37l5fKwA                  5
# 127401  iipnazeY9eoANJ37l5fKwA                  5
# 127402  yJ9FTZHLZRZL3voM12vDtQ                  5
# 127403  yJ9FTZHLZRZL3voM12vDtQ                  5
# 127404  vmFyWIz_goMNO7a2vpraLw                  5
#
#                                                    Review  \
# 0       sonny's bbq is one of my favorite restaurants ...
# 1       love this place \n\nwish there was one close t...
# 2       really dark, no atmosphere to speak of.  food ...
# 3       love this place. i'm in wc at least 4-5 times ...
# 4       this evening i stopped by this sonny's on my w...
# ...                                                   ...
# 127400  i went to have a mug packaged and shipped, and...
# 127401  i stopped in to ship a box to california, wher...
# 127402  this food was delicious!! ordered: beef & broc...
# 127403  this place is legit. no f cookie but i can ove...
# 127404  as advertised- a positive experience and thoro...
#
#                     Negocio          Direccion_Negocio           city  \
# 0               Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel
# 1               Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel
# 2               Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel
# 3               Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel
# 4               Sonny's BBQ  5324 Bruce B. Downs Blvd.  Wesley Chapel
# ...                     ...                        ...            ...
# 127400     Post Pack & Ship               637 W Hwy 50       O'Fallon
# 127401     Post Pack & Ship               637 W Hwy 50       O'Fallon
# 127402      Chinese Express       311 De Baliviere Ave    Saint Louis
# 127403      Chinese Express       311 De Baliviere Ave    Saint Louis
# 127404  Plainfield Eye Care             900 Edwards Dr     Plainfield
#
#             Estado  Estrellas_Review  Numero_reviews  \
# 0       California               3.0              82
# 1       California               3.0              82
# 2       California               3.0              82
# 3       California               3.0              82
# 4       California               3.0              82
# ...            ...               ...             ...
# 127400  California               5.0               9
# 127401  California               5.0               9
# 127402  California               3.5               7
# 127403  California               3.5               7
# 127404  California               4.5              10
#
#                                                attributes  \
# 0       {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 1       {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 2       {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 3       {'NoiseLevel': "'average'", 'Caters': 'True', ...
# 4       {'NoiseLevel': "'average'", 'Caters': 'True', ...
# ...                                                   ...
# 127400                                                NaN
# 127401                                                NaN
# 127402  {'RestaurantsPriceRange2': '1', 'GoodForKids':...
# 127403  {'RestaurantsPriceRange2': '1', 'GoodForKids':...
# 127404  {'ByAppointmentOnly': 'True', 'BusinessParking...
#
#                                     Clasificacion Negocio  \
# 0       Barbeque, Event Planning & Services, Restauran...
# 1       Barbeque, Event Planning & Services, Restauran...
# 2       Barbeque, Event Planning & Services, Restauran...
# 3       Barbeque, Event Planning & Services, Restauran...
# 4       Barbeque, Event Planning & Services, Restauran...
# ...                                                   ...
# 127400  Packing Services, Shipping Centers, Local Serv...
# 127401  Packing Services, Shipping Centers, Local Serv...
# 127402                               Restaurants, Chinese
# 127403                               Restaurants, Chinese
# 127404  Optometrists, Shopping, Medical Supplies, Doct...
#
#                                                     hours  anio  mes  dia
# 0       {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017    4    2
# 1       {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017    5   21
# 2       {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2017    3   14
# 3       {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018   11   25
# 4       {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...  2018   11    3
# ...                                                   ...   ...  ...  ...
# 127400                                                NaN  2017    5   17
# 127401                                                NaN  2018    6   25
# 127402  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  2018    1   27
# 127403  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  2018   10    9
# 127404  {'Monday': '8:0-19:0', 'Tuesday': '7:30-19:0',...  2021    7   13
#
# [127405 rows x 17 columns]

# %% [markdown]
# # Buscamos que estén las cadenas de restaurants con las que vamos a trabajar.

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process

# Ruta al archivo CSV
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/YelpEstados.csv"

# Cargar el archivo CSV en un DataFrame
restaurantes_df = pd.read_csv(ruta_csv)

# Cambiar el tipo de dato de la columna 'Negocio' a str
restaurantes_df['Negocio'] = restaurantes_df['Negocio'].astype(str)

# Crear una lista con las cadenas de restaurantes que deseas buscar
cadenas_de_restaurantes = ["KFC", "McDonald's", "Subway", "Starbucks", "Domino's Pizza"]

# Crear un diccionario para almacenar los recuentos de cada cadena
recuentos = {}

# Iterar sobre la lista de cadenas de restaurantes y buscar coincidencias difusas en el DataFrame
for cadena in cadenas_de_restaurantes:
    # Utilizar process.extract para encontrar las coincidencias más cercanas en el DataFrame
    coincidencias = process.extract(cadena, restaurantes_df['Negocio'], limit=10, scorer=fuzz.ratio)
    
    # Filtrar las coincidencias que superan un umbral de similitud (por ejemplo, 80)
    coincidencias_filtradas = [match for match in coincidencias if match[1] >= 80]
    
    # Contar cuántas veces aparece la cadena o las coincidencias similares en el DataFrame
    recuento = len(coincidencias_filtradas)
    recuentos[cadena] = recuento

# Imprimir los recuentos
for cadena, recuento in recuentos.items():
    print(f"{cadena}: {recuento} veces")
# Out:
# KFC: 10 veces
# McDonald's: 10 veces
# Subway: 10 veces
# Starbucks: 10 veces
# Domino's Pizza: 10 veces

# %% [markdown]
# # Filtramos el DataFrame por los años que tomamos en dos tramos para el análisis posterior y probar la carga incremental en la nube.

# %%
import pandas as pd

# Ruta al archivo CSV original
ruta_csv = "C:/Users/Fede/Desktop/ETL/3er_Demo/YelpEstados_Nombres.csv"

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(ruta_csv)

# Convertir la columna "Anio" a tipo datetime
df['anio'] = pd.to_datetime(df['anio'], format='%Y')

# Filtrar datos anteriores a 2021
df_2017_2020 = df[df['anio'] < '2021']

# Filtrar datos desde 2021 en adelante
df_desde_2021 = df[df['anio'] >= '2021']

# Ruta a los archivos CSV resultantes
ruta_csv_2017_2020 = "C:/Users/Fede/Desktop/ETL/3er_Demo/YelpRestaurante2017_2021.csv"
ruta_csv_desde_2021 = "C:/Users/Fede/Desktop/ETL/3er_Demo/YelpRestaurante2021.csv"

# Guardar los DataFrames filtrados en los archivos CSV correspondientes
df_2017_2020.to_csv(ruta_csv_2017_2020, index=False)
df_desde_2021.to_csv(ruta_csv_desde_2021, index=False)
